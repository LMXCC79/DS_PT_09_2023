# %% [markdown]
# ## ¿Qué es el Aprendizaje por Refuerzo?
#
#
# Seguramente ya conocerás las 2 grandes áreas de aprendizaje tradicional del Machine Learning, el aprendizaje supervisado y el aprendizaje no supervisado. Parece difícil que aquí hubiera espacio para otras opciones; sin embargo sí la hay y es el Aprendizaje por refuerzo. En aprendizaje por refuerzo (ó Reinforcement Learning en inglés) no tenemos una “etiqueta de salida”, por lo que no es de tipo supervisado y si bien estos algoritmos aprenden por sí mismos, tampoco son de tipo no supervisado, en donde se intenta clasificar grupos teniendo en cuenta alguna distancia entre muestras.
#
# ![foto1](img/areas-ml.png)
#
# ![foto4](img/1_YIETknPBlQQBF40DJxL8QA.png)
#
# Si nos ponemos a pensar, los problemas de ML supervisados y no supervisados son específicos de un caso de negocio en particular, sea de clasificación ó predicción, están muy delimitados, por ejemplo, clasificar “perros ó gatos“, ó agrupar “k=5” clusters. En contraste, en el mundo real contamos con múltiples variables que por lo general se interrelacionan y que dependen de otros casos de negocio y dan lugar a escenarios más grandes en donde tomar decisiones. Para conducir un coche no basta una inteligencia que pueda detectar un semáforo en rojo, verde ó amarillo; tendremos muchísimos factores -todos a la vez- a los que prestar atención: a qué velocidad vamos, estamos ante una curva?, hay peatones?, es de noche y debemos encender las luces?.
#
# Una solución sería tener múltiples máquinas de ML supervisadas y que interactúan entre si -y esto no estaría mal- ó podemos cambiar el enfoque… Y ahí aparece el Reinforcement Learning (RL) como una alternativa, tal vez de las más ambiciosas en las que se intenta integrar el Machine Learning en el mundo real, sobre todo aplicado a robots y maquinaria industrial.
#
# El Reinforcement Learning entonces, intentará hacer aprender a la máquina basándose en un esquema de “premios y castigos” -cómo con el perro de Pablov- en un entorno en donde hay que tomar acciones y que está afectado por múltiples variables que cambian con el tiempo.
#
# ![foto2](img/496302-1548589.jpg)
#
#
# ## Diferencias con “los clásicos”
#
# En los modelos de Aprendizaje Supervisado (o no supervisado) como redes neuronales, árboles, knn, etc, se intenta “minimizar la función coste”, reducir el error.
#
# En cambio en el RL se intenta “maximizar la recompensa“. Y esto puede ser, a pesar de a veces cometer errores ó de no ser óptimos.
#
# Componentes del RL
# El Reinforcement Learning propone un nuevo enfoque para hacer que nuestra máquina aprenda, para ello, postula los siguientes 2 componentes:
#
# el Agente: será nuestro modelo que queremos entrenar y que aprenda a tomar decisiones.
#
# Ambiente: será el entorno en donde interactúa y “se mueve” el agente. El ambiente contiene las limitaciones y reglas posibles a cada momento.
# Entre ellos hay una relación que se retroalimenta y cuenta con los siguientes nexos:
#
# Acción: las posibles acciones que puede tomar en un momento determinado el Agente.
#
# Estado (del ambiente): son los indicadores del ambiente de cómo están los diversos elementos que lo componen en ese momento.
#
# Recompensas (ó castigos!): a raíz de cada acción tomada por el Agente, podremos obtener un premio ó una penalización que orientarán al Agente en si lo está haciendo bien ó mal.
#
# ![foto3](img/premio-castigo.png)

# %% [markdown]
# ## Empecemos a trabajar Obreros..

# %%
#!pip install gym
# Out:
# Collecting gym
#   Using cached gym-0.26.2.tar.gz (721 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.18.0 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from gym) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from gym) (3.0.0)
# Collecting gym-notices>=0.0.4 (from gym)
#   Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml): started
#   Building wheel for gym (pyproject.toml): finished with status 'done'
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827632 sha256=13297bcf52724b25c4a78a9df2f11a12313c455de9737b3bf1c3d7f677f5d18c
#   Stored in directory: c:\users\sandia\appdata\local\pip\cache\wheels\1c\77\9e\9af5470201a0b0543937933ee99ba884cd237d2faefe8f4d37
# Successfully built gym
# Installing collected packages: gym-notices, gym
# Successfully installed gym-0.26.2 gym-notices-0.0.8
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
import random
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Cart Pole.
#
# ![foto5](img/0-923627-95182.gif)
#
# Se trata de un péndulo que está en posición vertical y debemos mover el carro de abajo para que no caiga a ninguno de los lados.
#
# Este entorno es un problema clásico y como tal, ya está diseñado por nosotros en diferentes librerías. Nosotros usaremos OpenAI Gym. Se trata de una librería que provee de varios entornos interesantes para poner a prueba nuestros algoritmos, con representación gráfica de los mismos.
#
# Este entorno se caracteriza por tener cuatro entradas: posición del carro, velocidad del carro, ángulo del péndulo y velocidad angular del péndulo. Y dos acciones: acelerar a la izquierda y acelerar a la derecha. Las recompensas son 1 por cada acción tomada. El episodio finaliza cuando el ángulo del péndulo supera los 12 grados, el carro se aleja demasiado del centro y cuando el episodio alcanza los 200 pasos.
#
# Vamos a ver como funciona la interfaz Gym para que luego seamos capaces de crear nuestros propios entornos. Esta se compone de:
#
# Una clase que hereda de **gym.Env**
#
# Un constructor donde inicializamos, como mínimo, self.action_space, self.observation_space y opcionalmente self.reward_range y parámetros internos del entorno nuestro. Estas dos primeras deben ser de algún subtipo **gym.spaces**. Los más normales son **Discrete**, que es básicamente un valor activado sobre N posibles y Box, que es una matriz de características (podemos especificar la forma para que sea unidimensional, o que tenga más dimensiones), que contiene números.
# Es muy habitual que las observaciones sean de tipo Box, ya que se miden varias características a la vez, con números decimales y **Discrete** sea para las acciones ya que tomamos una acción de N posibles. Pero otras combinaciones son posibles y existen más tipos de **gym.spaces**. Si vamos a introducir características diferentes dentro del mismo Box es muy conveniente normalizar los datos entre -1 y 1. self.reward_range, al contrario, es una tupla en la que se especifica el valor máximo y el mínimo que pueden alcanzar las recompensas.
#
# Un método **reset**, que reinicia el entorno y devuelve una observación inicial. Estas observaciones, deberán devolverse con NumPy si son de tipo Box y coincidir con lo declarado en el constructor en cuanto a forma y tipos.
#
# Un método **step** que toma una acción y devuelve una tupla con cuatro valores: nueva observación, recompensa, un boolean de si el episodio ha acabado ya o no y un diccionario de información extra (no usado por los algoritmos).
#
# Opcionalmente pueden llevar instrucciones sobre como renderizar el entorno y así ver en vivo o en vídeo el funcionamiento de los algoritmos. Principalmente se controla a través del método **render**.

# %% [markdown]
# [cartpole](https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py)

# %%
env=gym.make('CartPole-v1') # Crea el entorno de juego correspondiente

#Opcional, establezca un número aleatorio para que el proceso se pueda repetir

env=env.unwrapped #Opcional, agregue restricciones al medio ambiente, beneficioso para la capacitación

# ---------------------- Espacio de acción y espacio de estado --------------------- #

print("Action Space {}".format(env.action_space)) # Posibles Movimientos

print("State Space {}".format(env.observation_space))
# Out:
# Action Space Discrete(2)
# State Space Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env = gym.make('CartPole-v1')

# %%
env.reset()
for _ in range(500):
    env.render()
    env.step(env.action_space.sample())

# %%
env.close()

# %% [markdown]
# Bien ahora tenemos un carrito idiota que no hace nada solo moverse...

# %% [markdown]
# Si queremos tomar acciones que son mejores que las aleatorias en cada paso, entonces sería bueno comprender realmente cómo nuestras acciones afectan el medio ambiente. A
# La función de paso del entorno devolverá la información que necesitamos. La función paso devuelve cuatro valores, la siguiente es la información específica:
#
# Observación (objet): un objeto relacionado con el entorno describe el entorno que observa, como la información de píxeles de la cámara, el ángulo y la velocidad angular del robot y el estado del tablero en un juego de mesa.
#
# recompensa (float): La suma de todas las recompensas obtenidas de acciones anteriores. Los diferentes entornos tienen diferentes métodos de cálculo, pero el objetivo siempre ha sido aumentar tus recompensas totales.
#
# done (booleano): para determinar si es el momento de restablecer el entorno, la mayoría de las tareas se dividen en episodios claramente definidos, y done es True para indicar que el episodio ha terminado.
#
# info (dict): información de diagnóstico para depuración. A veces también es útil para aprender (por ejemplo, puede contener la probabilidad original después del último cambio de estado del entorno). Pero la evaluación formal del agente no permite el uso de esta información para el aprendizaje

# %% [markdown]
# [cartpole.py](./cartpole.py)

# %%
maximo=[]
for i_episode in range(20):
    observation = env.reset()
    observation =observation[0]
    for t in range(100):
        action = int(observation[2] > 0.0 and observation[3] > 0.0)
        if observation[0] >= 2.0:
            action=0  
        elif observation <= -2.0:
            action=1
        observation, reward, done, _, info= env.step(action)
        if done:
            maximo.append(t+1)
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 9
#       7 if observation[0] >= 2.0:
#       8     action=0
# ----> 9 elif observation <= -2.0:
#      10     action=1
#      11 observation, reward, done, _, info= env.step(action)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
print(max(maximo))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 print(max(maximo))
#
# ValueError: max() arg is an empty sequence

# %% [markdown]
# ## Stable Baselines
#
# Este algoritmo, DQN, es muy popular, y se encuentra implementado en diferentes librerías. Una de las más interesantes es Stable Baselines 3, que intenta ser el sklearn del aprendizaje por refuerzo. Usa PyTorch internamente. Con Stable Baselines 3, debemos proporcionar un entorno que siga la interfaz Gym y ajustar los hiperparámetros. En el caso de DQN los hiperparámetros más importantes son:
#
# - **policy** - La política a usar del modelo. Casi siempre MlpPolicy. Si la entrada son imágenes, CnnPolicy.
# - **env** - El entorno sobre el que vamos a aprender. Debe implementar la interfaz OpenAI Gym
# - **learning_rate** - Ratio de aprendizaje de la red neuronal
# - **buffer_size** - El tamaño del buffer que almacenará las transiciones del "experience replay".
# - **batch_size** - Tamaño del batch que se usa para reentrenar.
# - **learning_starts** - Cuantos steps debe dar el modelo antes de empezar a aprender la red neuronal.
# - **gamma** - el factor de descuento. En posts anteriores hemos hablado de él.
# - **train_freq** - Cada cuantos steps se reentrena el modelo.
# - **gradient_steps** - Cuantos pasos de gradiente se dan al entrenar. Por defecto, 1.
# - **target_update_interval** - Cada cuantos steps se actualiza el "fixed Q-target".
# - **policy_kwargs** - Ajustes de la política. En el caso de MlpPolicy podremos ajustar la forma de la red,
#                     así como las funciones de activación   y más detalles.

# %%
#!pip install stable-baselines3
# Out:
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#                                               0.0/181.7 kB ? eta -:--:--
#      -----------------------------------   174.1/181.7 kB 10.2 MB/s eta 0:00:01
#      -------------------------------------- 181.7/181.7 kB 5.5 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#                                               0.0/953.9 kB ? eta -:--:--
#      ------------------------------------- 953.9/953.9 kB 30.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from stable-baselines3) (1.25.2)
# Collecting torch>=1.13 (from stable-baselines3)
#   Downloading torch-2.2.1-cp311-cp311-win_amd64.whl (198.6 MB)
#                                               0.0/198.6 MB ? eta -:--:--
#                                              1.7/198.6 MB 35.9 MB/s eta 0:00:06
#                                              3.7/198.6 MB 46.7 MB/s eta 0:00:05
#                                              5.0/198.6 MB 40.3 MB/s eta 0:00:05
#      -                                       6.8/198.6 MB 43.5 MB/s eta 0:00:05
#      -                                       8.6/198.6 MB 41.9 MB/s eta 0:00:05
#      -                                      10.4/198.6 MB 43.7 MB/s eta 0:00:05
#      --                                     11.7/198.6 MB 40.9 MB/s eta 0:00:05
#      --                                     13.7/198.6 MB 40.9 MB/s eta 0:00:05
#      --                                     15.4/198.6 MB 40.9 MB/s eta 0:00:05
#      ---                                    16.7/198.6 MB 40.9 MB/s eta 0:00:05
#      ---                                    18.8/198.6 MB 40.9 MB/s eta 0:00:05
#      ---                                    19.6/198.6 MB 38.5 MB/s eta 0:00:05
#      ----                                   21.0/198.6 MB 36.3 MB/s eta 0:00:05
#      ----                                   22.9/198.6 MB 40.9 MB/s eta 0:00:05
#      ----                                   24.3/198.6 MB 38.5 MB/s eta 0:00:05
#      -----                                  26.1/198.6 MB 40.9 MB/s eta 0:00:05
#      -----                                  27.8/198.6 MB 38.5 MB/s eta 0:00:05
#      -----                                  29.8/198.6 MB 40.9 MB/s eta 0:00:05
#      ------                                 31.5/198.6 MB 40.9 MB/s eta 0:00:05
#      ------                                 33.3/198.6 MB 40.9 MB/s eta 0:00:05
#      ------                                 34.9/198.6 MB 40.9 MB/s eta 0:00:04
#      ------                                 36.3/198.6 MB 36.4 MB/s eta 0:00:05
#      -------                                38.4/198.6 MB 38.6 MB/s eta 0:00:05
#      -------                                40.3/198.6 MB 38.5 MB/s eta 0:00:05
#      --------                               41.9/198.6 MB 40.9 MB/s eta 0:00:04
#      --------                               43.6/198.6 MB 43.5 MB/s eta 0:00:04
#      --------                               44.7/198.6 MB 38.5 MB/s eta 0:00:05
#      --------                               46.2/198.6 MB 40.9 MB/s eta 0:00:04
#      ---------                              48.4/198.6 MB 38.6 MB/s eta 0:00:04
#      ---------                              50.4/198.6 MB 40.9 MB/s eta 0:00:04
#      ---------                              52.2/198.6 MB 38.5 MB/s eta 0:00:04
#      ----------                             53.4/198.6 MB 36.4 MB/s eta 0:00:04
#      ----------                             55.3/198.6 MB 43.7 MB/s eta 0:00:04
#      ----------                             56.6/198.6 MB 40.9 MB/s eta 0:00:04
#      -----------                            58.6/198.6 MB 38.5 MB/s eta 0:00:04
#      -----------                            60.2/198.6 MB 36.3 MB/s eta 0:00:04
#      -----------                            62.3/198.6 MB 38.5 MB/s eta 0:00:04
#      ------------                           64.0/198.6 MB 38.6 MB/s eta 0:00:04
#      ------------                           66.1/198.6 MB 40.9 MB/s eta 0:00:04
#      ------------                           67.5/198.6 MB 38.6 MB/s eta 0:00:04
#      -------------                          69.4/198.6 MB 38.5 MB/s eta 0:00:04
#      -------------                          71.2/198.6 MB 40.9 MB/s eta 0:00:04
#      -------------                          72.9/198.6 MB 36.4 MB/s eta 0:00:04
#      --------------                         75.0/198.6 MB 40.9 MB/s eta 0:00:04
#      --------------                         75.8/198.6 MB 36.4 MB/s eta 0:00:04
#      --------------                         77.9/198.6 MB 38.5 MB/s eta 0:00:04
#      ---------------                        79.6/198.6 MB 38.5 MB/s eta 0:00:04
#      ---------------                        81.7/198.6 MB 40.9 MB/s eta 0:00:03
#      ---------------                        83.4/198.6 MB 38.6 MB/s eta 0:00:03
#      ----------------                       85.1/198.6 MB 36.4 MB/s eta 0:00:04
#      ----------------                       87.1/198.6 MB 40.9 MB/s eta 0:00:03
#      ----------------                       88.4/198.6 MB 40.9 MB/s eta 0:00:03
#      -----------------                      90.4/198.6 MB 40.9 MB/s eta 0:00:03
#      -----------------                      92.1/198.6 MB 38.5 MB/s eta 0:00:03
#      ------------------                     94.5/198.6 MB 38.5 MB/s eta 0:00:03
#      ------------------                     96.6/198.6 MB 40.9 MB/s eta 0:00:03
#      ------------------                     98.7/198.6 MB 46.9 MB/s eta 0:00:03
#      -------------------                    99.8/198.6 MB 40.9 MB/s eta 0:00:03
#      ------------------                    101.7/198.6 MB 40.9 MB/s eta 0:00:03
#      -------------------                   103.8/198.6 MB 40.9 MB/s eta 0:00:03
#      -------------------                   106.1/198.6 MB 40.9 MB/s eta 0:00:03
#      --------------------                  108.3/198.6 MB 40.9 MB/s eta 0:00:03
#      --------------------                  110.3/198.6 MB 46.7 MB/s eta 0:00:02
#      --------------------                  112.0/198.6 MB 46.7 MB/s eta 0:00:02
#      ---------------------                 113.6/198.6 MB 40.9 MB/s eta 0:00:03
#      ---------------------                 115.7/198.6 MB 40.9 MB/s eta 0:00:03
#      ---------------------                 117.3/198.6 MB 40.9 MB/s eta 0:00:02
#      ----------------------                119.3/198.6 MB 40.9 MB/s eta 0:00:02
#      ----------------------                121.3/198.6 MB 40.9 MB/s eta 0:00:02
#      ----------------------                123.4/198.6 MB 43.7 MB/s eta 0:00:02
#      -----------------------               125.1/198.6 MB 40.9 MB/s eta 0:00:02
#      -----------------------               126.6/198.6 MB 40.9 MB/s eta 0:00:02
#      ------------------------              129.2/198.6 MB 43.5 MB/s eta 0:00:02
#      ------------------------              130.7/198.6 MB 40.9 MB/s eta 0:00:02
#      ------------------------              133.1/198.6 MB 40.9 MB/s eta 0:00:02
#      -------------------------             134.8/198.6 MB 40.9 MB/s eta 0:00:02
#      -------------------------             135.6/198.6 MB 36.4 MB/s eta 0:00:02
#      -------------------------             136.6/198.6 MB 34.4 MB/s eta 0:00:02
#      -------------------------             138.7/198.6 MB 32.7 MB/s eta 0:00:02
#      --------------------------            140.5/198.6 MB 32.7 MB/s eta 0:00:02
#      --------------------------            141.3/198.6 MB 31.2 MB/s eta 0:00:02
#      --------------------------            142.1/198.6 MB 28.5 MB/s eta 0:00:02
#      --------------------------            143.3/198.6 MB 25.2 MB/s eta 0:00:03
#      --------------------------            144.1/198.6 MB 24.2 MB/s eta 0:00:03
#      ---------------------------           145.9/198.6 MB 27.3 MB/s eta 0:00:02
#      ---------------------------           147.7/198.6 MB 28.5 MB/s eta 0:00:02
#      ---------------------------           149.6/198.6 MB 27.3 MB/s eta 0:00:02
#      ----------------------------          151.5/198.6 MB 29.7 MB/s eta 0:00:02
#      ----------------------------          153.5/198.6 MB 38.5 MB/s eta 0:00:02
#      ----------------------------          154.5/198.6 MB 38.5 MB/s eta 0:00:02
#      -----------------------------         156.1/198.6 MB 36.4 MB/s eta 0:00:02
#      -----------------------------         158.5/198.6 MB 38.5 MB/s eta 0:00:02
#      -----------------------------         160.1/198.6 MB 38.5 MB/s eta 0:00:01
#      ------------------------------        162.0/198.6 MB 38.6 MB/s eta 0:00:01
#      ------------------------------        163.8/198.6 MB 38.6 MB/s eta 0:00:01
#      ------------------------------        165.8/198.6 MB 40.9 MB/s eta 0:00:01
#      -------------------------------       167.5/198.6 MB 38.5 MB/s eta 0:00:01
#      -------------------------------       169.9/198.6 MB 43.7 MB/s eta 0:00:01
#      -------------------------------       171.7/198.6 MB 43.7 MB/s eta 0:00:01
#      --------------------------------      173.2/198.6 MB 40.9 MB/s eta 0:00:01
#      --------------------------------      174.9/198.6 MB 40.9 MB/s eta 0:00:01
#      --------------------------------      177.0/198.6 MB 40.9 MB/s eta 0:00:01
#      ---------------------------------     179.0/198.6 MB 40.9 MB/s eta 0:00:01
#      ---------------------------------     180.8/198.6 MB 38.5 MB/s eta 0:00:01
#      ----------------------------------    182.9/198.6 MB 40.9 MB/s eta 0:00:01
#      ----------------------------------    183.7/198.6 MB 40.9 MB/s eta 0:00:01
#      ----------------------------------    186.3/198.6 MB 40.9 MB/s eta 0:00:01
#      ----------------------------------    187.6/198.6 MB 38.5 MB/s eta 0:00:01
#      -----------------------------------   189.3/198.6 MB 38.5 MB/s eta 0:00:01
#      -----------------------------------   190.9/198.6 MB 38.6 MB/s eta 0:00:01
#      -----------------------------------   192.8/198.6 MB 36.3 MB/s eta 0:00:01
#      ------------------------------------  194.9/198.6 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  196.3/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.3/198.6 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  198.6/198.6 MB 36.4 MB/s eta 0:00:01
#      -------------------------------------- 198.6/198.6 MB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from stable-baselines3) (3.0.0)
# Requirement already satisfied: pandas in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from stable-baselines3) (2.1.1)
# Requirement already satisfied: matplotlib in c:\users\sandia\appdata\roaming\python\python311\site-packages (from stable-baselines3) (3.7.5)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.10.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: filelock in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.13->stable-baselines3) (3.13.1)
# Collecting sympy (from torch>=1.13->stable-baselines3)
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#                                               0.0/5.7 MB ? eta -:--:--
#      ---------                                1.4/5.7 MB 44.9 MB/s eta 0:00:01
#      ---------------------                    3.1/5.7 MB 39.6 MB/s eta 0:00:01
#      ----------------------------------       4.9/5.7 MB 39.2 MB/s eta 0:00:01
#      ---------------------------------------  5.7/5.7 MB 36.7 MB/s eta 0:00:01
#      ---------------------------------------- 5.7/5.7 MB 26.3 MB/s eta 0:00:00
# Requirement already satisfied: networkx in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.13->stable-baselines3) (3.2)
# Requirement already satisfied: jinja2 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.13->stable-baselines3) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.13->stable-baselines3) (2024.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->stable-baselines3) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->stable-baselines3) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sandia\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->stable-baselines3) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->stable-baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sandia\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from pandas->stable-baselines3) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\sandia\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sandia\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.5)
# Collecting mpmath>=0.19 (from sympy->torch>=1.13->stable-baselines3)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#                                               0.0/536.2 kB ? eta -:--:--
#      ------------------------------------  532.5/536.2 kB 32.6 MB/s eta 0:00:01
#      ------------------------------------- 536.2/536.2 kB 11.2 MB/s eta 0:00:00
# Installing collected packages: mpmath, farama-notifications, sympy, gymnasium, torch, stable-baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 mpmath-1.3.0 stable-baselines3-2.2.1 sympy-1.12 torch-2.2.1
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from stable_baselines3 import DQN
# Out:
# WARNING:tensorflow:From c:\Users\Sandia\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
env = gym.make("CartPole-v1", render_mode="human")
env.reset()
for _ in range(100):
    env.render()
    env.step(env.action_space.sample())

# %%
env.close()

# %%
# !pip install shimmy>=0.2.1
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
model = DQN(
    "MlpPolicy",
    env,
    learning_rate=1e-3,
    buffer_size=50000,
    learning_starts=10000,
    batch_size=64,
    gamma=0.999,
    gradient_steps=1,
    train_freq=20,
    target_update_interval=2000,
    verbose=1
    )
model.learn(total_timesteps=500_000)
model.save("dqn_cartpole")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 6107     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 91       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.5     |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 6075     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 212      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.1     |
# |    ep_rew_mean      | 28.1     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 5464     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 337      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.4     |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5210     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 406      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.1     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 5027     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 522      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.3     |
# |    ep_rew_mean      | 25.3     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 5000     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 607      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.8     |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 5028     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 693      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4975     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 759      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 5024     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 844      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 5025     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 911      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 5116     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1068     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 5054     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1154     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.6     |
# |    ep_rew_mean      | 24.6     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 5143     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1278     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | 24.5     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 5166     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 5135     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1444     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 5129     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1542     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 5150     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.7     |
# |    ep_rew_mean      | 24.7     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 5241     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 5258     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 5231     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4786     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2027     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4870     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2123     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4911     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2231     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4934     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4966     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2420     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4947     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4976     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2622     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4984     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 5000     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2815     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4996     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4960     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2988     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4973     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3055     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4966     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3106     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 5006     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3231     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 4983     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3297     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 5006     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 5027     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3470     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 5042     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3543     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 5065     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3638     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 5114     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 5162     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3863     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 5154     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3930     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 5158     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 5175     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4128     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 5187     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 5192     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4271     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 5205     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 5248     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 5248     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4529     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 5283     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4644     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 5316     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 5232     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 5208     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5010     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 5216     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5106     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 5189     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 5204     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 5198     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 5207     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5491     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 5214     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 5220     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5712     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 5219     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5763     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 5237     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5850     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 5276     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.6     |
# |    ep_rew_mean      | 24.6     |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 5293     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 5304     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6162     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 5317     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6251     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 5320     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6334     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 5331     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6429     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 5325     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6498     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 5332     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6606     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 5336     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 5338     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6750     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 5339     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6804     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 5336     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6903     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 5369     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7059     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 5379     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 5379     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 5375     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 5380     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 5392     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 5396     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7578     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 5389     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7662     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 5390     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7756     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 5386     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 5387     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 5380     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 5369     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 5380     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8176     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 5382     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 5380     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8316     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 5383     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8396     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 5391     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8485     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 5384     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 5380     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8651     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 5382     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8714     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 5391     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 5396     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8905     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 5397     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 5411     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9107     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 5410     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 5419     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 5412     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9335     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 5415     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9416     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 5424     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9517     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 5422     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9598     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 5426     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 5429     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9737     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 5424     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 5314     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9914     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 5304     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9981     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 4709     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10063    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.52     |
# |    n_updates        | 3        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 4557     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10186    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.407    |
# |    n_updates        | 9        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 4393     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10301    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.317    |
# |    n_updates        | 15       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 4327     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10378    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.284    |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 4247     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10475    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.206    |
# |    n_updates        | 23       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 4202     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10522    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.19     |
# |    n_updates        | 26       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 4155     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10575    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.165    |
# |    n_updates        | 28       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 4078     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10640    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.148    |
# |    n_updates        | 31       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 4009     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10702    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0776   |
# |    n_updates        | 35       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 3931     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10839    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0432   |
# |    n_updates        | 41       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 3896     |
# ...
# |    time_elapsed     | 406      |
# |    total_timesteps  | 468961   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.016    |
# |    n_updates        | 22948    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6508     |
# |    fps              | 1153     |
# |    time_elapsed     | 406      |
# |    total_timesteps  | 469351   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0299   |
# |    n_updates        | 22967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6512     |
# |    fps              | 1153     |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 469850   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0238   |
# |    n_updates        | 22992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | 99       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6516     |
# |    fps              | 1153     |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 470006   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.352    |
# |    n_updates        | 23000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | 95.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6520     |
# |    fps              | 1153     |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 470055   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.142    |
# |    n_updates        | 23002    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | 93.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6524     |
# |    fps              | 1153     |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 470420   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.92     |
# |    n_updates        | 23020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | 93.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6528     |
# |    fps              | 1153     |
# |    time_elapsed     | 408      |
# |    total_timesteps  | 470794   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0338   |
# |    n_updates        | 23039    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | 94.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6532     |
# |    fps              | 1153     |
# |    time_elapsed     | 408      |
# |    total_timesteps  | 471289   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0215   |
# |    n_updates        | 23064    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | 94.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6536     |
# |    fps              | 1153     |
# |    time_elapsed     | 408      |
# |    total_timesteps  | 471673   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0204   |
# |    n_updates        | 23083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95       |
# |    ep_rew_mean      | 95       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6540     |
# |    fps              | 1153     |
# |    time_elapsed     | 409      |
# |    total_timesteps  | 472224   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0373   |
# |    n_updates        | 23111    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | 95.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6544     |
# |    fps              | 1154     |
# |    time_elapsed     | 409      |
# |    total_timesteps  | 472727   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.96     |
# |    n_updates        | 23136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | 97.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6548     |
# |    fps              | 1154     |
# |    time_elapsed     | 410      |
# |    total_timesteps  | 473262   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.053    |
# |    n_updates        | 23163    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.9     |
# |    ep_rew_mean      | 97.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6552     |
# |    fps              | 1154     |
# |    time_elapsed     | 410      |
# |    total_timesteps  | 473659   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.9      |
# |    n_updates        | 23182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.6     |
# |    ep_rew_mean      | 97.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6556     |
# |    fps              | 1154     |
# |    time_elapsed     | 410      |
# |    total_timesteps  | 474060   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0926   |
# |    n_updates        | 23202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6560     |
# |    fps              | 1154     |
# |    time_elapsed     | 411      |
# |    total_timesteps  | 475480   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.04     |
# |    n_updates        | 23273    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6564     |
# |    fps              | 1154     |
# |    time_elapsed     | 412      |
# |    total_timesteps  | 476074   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0525   |
# |    n_updates        | 23303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 127      |
# |    ep_rew_mean      | 127      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6568     |
# |    fps              | 1154     |
# |    time_elapsed     | 413      |
# |    total_timesteps  | 477671   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0409   |
# |    n_updates        | 23383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6572     |
# |    fps              | 1154     |
# |    time_elapsed     | 415      |
# |    total_timesteps  | 479193   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0258   |
# |    n_updates        | 23459    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6576     |
# |    fps              | 1154     |
# |    time_elapsed     | 416      |
# |    total_timesteps  | 480510   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0493   |
# |    n_updates        | 23525    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6580     |
# |    fps              | 1154     |
# |    time_elapsed     | 417      |
# |    total_timesteps  | 481729   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0305   |
# |    n_updates        | 23586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6584     |
# |    fps              | 1154     |
# |    time_elapsed     | 418      |
# |    total_timesteps  | 482593   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.81     |
# |    n_updates        | 23629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6588     |
# |    fps              | 1153     |
# |    time_elapsed     | 419      |
# |    total_timesteps  | 484090   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0644   |
# |    n_updates        | 23704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 184      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6592     |
# |    fps              | 1153     |
# |    time_elapsed     | 420      |
# |    total_timesteps  | 485720   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0259   |
# |    n_updates        | 23785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6596     |
# |    fps              | 1153     |
# |    time_elapsed     | 422      |
# |    total_timesteps  | 487252   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0172   |
# |    n_updates        | 23862    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6600     |
# |    fps              | 1152     |
# |    time_elapsed     | 424      |
# |    total_timesteps  | 488888   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.7      |
# |    n_updates        | 23944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6604     |
# |    fps              | 1152     |
# |    time_elapsed     | 425      |
# |    total_timesteps  | 490602   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0426   |
# |    n_updates        | 24030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 230      |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6608     |
# |    fps              | 1151     |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 492393   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0605   |
# |    n_updates        | 24119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 241      |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6612     |
# |    fps              | 1151     |
# |    time_elapsed     | 428      |
# |    total_timesteps  | 493989   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.74     |
# |    n_updates        | 24199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | 258      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6616     |
# |    fps              | 1151     |
# |    time_elapsed     | 430      |
# |    total_timesteps  | 495839   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0394   |
# |    n_updates        | 24291    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 278      |
# |    ep_rew_mean      | 278      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6620     |
# |    fps              | 1151     |
# |    time_elapsed     | 432      |
# |    total_timesteps  | 497839   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0629   |
# |    n_updates        | 24391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | 294      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6624     |
# |    fps              | 1151     |
# |    time_elapsed     | 433      |
# |    total_timesteps  | 499839   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.71     |
# |    n_updates        | 24491    |
# ----------------------------------

# %%
model = DQN.load("dqn_cartpole")

obs, info = env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env.step(action)
    env.render()
    if done:
        obs, info = env.reset()

# %%
env.close()

# %% [markdown]
# Ahora vamos con otro ejemplo..

# %% [markdown]
# ## MountainCar
#
# ![foto7](img/MountainCar.gif)

# %%
env = gym.make('MountainCar-v0')

# %%
env.reset()
for i in range(300):
    env.render()
    env.step(env.action_space.sample()) # accion random

# %%
env.close()

# %%
for i_episode in range(20):
    observation = env.reset()
    for t in range(100):
        env.render()
        print(observation)
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break

# %% [markdown]
# [mountaincar.py](./mountaincar.py)

# %% [markdown]
# Otro ejemplo..

# %% [markdown]
# ## Taxi
#
# ![foto8](img/ezgif.com-video-to-gif1.gif)

# %%
#!pip install gym[toy_text]

# Modificando la línea env = gym.make("Taxi-v3").env por esta: env = gym.make("Taxi-v3", render_mode="ansi").env
#Ahora renderiza

# %%
env = gym.make("Taxi-v3").env
env.reset()
env.render()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Sandia\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\envs\toy_text\taxi.py:294, in TaxiEnv._render_gui(self, mode)
#     293 try:
# --> 294     import pygame  # dependency to pygame only if rendering with human
#     295 except ImportError:
#
# ModuleNotFoundError: No module named 'pygame'
#
# During handling of the above exception, another exception occurred:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[20], line 3
#       1 env = gym.make("Taxi-v3").env
#       2 env.reset()
# ----> 3 env.render()
#
# File c:\Users\Sandia\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\wrappers\order_enforcing.py:51, in OrderEnforcing.render(self, *args, **kwargs)
#      46 if not self._disable_render_order_enforcing and not self._has_reset:
#      47     raise ResetNeeded(
#      48         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      49         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50     )
# ---> 51 return self.env.render(*args, **kwargs)
#
# File c:\Users\Sandia\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\wrappers\env_checker.py:53, in PassiveEnvChecker.render(self, *args, **kwargs)
#      51 if self.checked_render is False:
#      52     self.checked_render = True
# ---> 53     return env_render_passive_checker(self.env, *args, **kwargs)
#      54 else:
#      55     return self.env.render(*args, **kwargs)
#
# File c:\Users\Sandia\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:316, in env_render_passive_checker(env, *args, **kwargs)
#     310     else:
#     311         assert env.render_mode is None or env.render_mode in render_modes, (
#     312             "The environment was initialized successfully however with an unsupported render mode. "
#     313             f"Render mode: {env.render_mode}, modes: {render_modes}"
#     314         )
# --> 316 result = env.render(*args, **kwargs)
#     318 # TODO: Check that the result is correct
#     320 return result
#
# File c:\Users\Sandia\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\envs\toy_text\taxi.py:290, in TaxiEnv.render(self)
#     288     return self._render_text()
#     289 else:  # self.render_mode in {"human", "rgb_array"}:
# --> 290     return self._render_gui(self.render_mode)
#
# File c:\Users\Sandia\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\envs\toy_text\taxi.py:296, in TaxiEnv._render_gui(self, mode)
#     294     import pygame  # dependency to pygame only if rendering with human
#     295 except ImportError:
# --> 296     raise DependencyNotInstalled(
#     297         "pygame is not installed, run `pip install gym[toy_text]`"
#     298     )
#     300 if self.window is None:
#     301     pygame.init()
#
# DependencyNotInstalled: pygame is not installed, run `pip install gym[toy_text]`

# %% [markdown]
# Hay 4 ubicaciones (etiquetadas con letras diferentes), y nuestro trabajo es recoger al pasajero en una ubicación y dejarlo en otra. Recibimos +20 puntos por una entrega exitosa y perdemos 1 punto por cada paso de tiempo que toma. También hay una penalización de 10 puntos por acciones ilegales de recogida y entrega.

# %%
print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))

# %%
print(env.s)

# %% [markdown]
# Como se verifica en las impresiones, tenemos un espacio de acción de tamaño 6 y un espacio de estado de tamaño 500. Como verá, nuestro algoritmo RL no necesitará más información que estas dos cosas. Todo lo que necesitamos es una forma de identificar un estado de manera única asignando un número único a cada estado posible, y RL aprende a elegir un número de acción del 0 al 5 donde:
#
# - 0 = sur
# - 1 = norte
# - 2 = este
# - 3 = oeste
# - 4 = recoger
# - 5 = dejar

# %%
state = env.encode(3, 1, 2, 0) # (taxi row, taxi column, passenger index, destination index)
print("State:", state)

env.s = state
env.render()

# %%
env.s = 328  # set environment to illustration's state

epochs = 0
penalties, reward = 0, 0

frames = [] # for animation

done = False

while not done:
    action = env.action_space.sample()
    state, reward, done, info = env.step(action)
    # Añade +1 a la variable penaltie cuando el reward sea -10
    if reward == -10:
        penalties = penalties + 1
    # Put each rendered frame into dict for animation
    frames.append({
        'frame': env.render(mode='ansi'),
        'state': state,
        'action': action,
        'reward': reward
        }
    )

    epochs += 1

print("Timesteps taken: {}".format(epochs))
print("Penalties incurred: {}".format(penalties))

# %%
from IPython.display import clear_output
from time import sleep

def print_frames(frames):
    for i, frame in enumerate(frames):
        clear_output(wait=True)
        print(frame['frame'])
        print(f"Timestep: {i + 1}")
        print(f"State: {frame['state']}")
        print(f"Action: {frame['action']}")
        print(f"Reward: {frame['reward']}")
        sleep(.1)
        
print_frames(frames)

# %%
# Crea un array2d de ceros del tamaño de los diferentes estados y las diferentes posibles acciones
q_table = np.zeros([env.observation_space.n, env.action_space.n])
q_table

# %%
random.uniform(0, 1)

# %%
# %%time
"""Training the agent"""

import random
from IPython.display import clear_output
q_table = np.zeros([env.observation_space.n, env.action_space.n])

# Hyperparameters
alpha = 0.1
gamma = 0.6
epsilon = 0.1

# For plotting metrics
all_epochs = []
all_penalties = []

for i in range(1, 100001):
    state = env.reset()

    epochs, penalties, reward, = 0, 0, 0
    done = False
    
    while not done:
        if random.uniform(0, 1) < epsilon:
            action = env.action_space.sample() # Explore action space
        else:
            action = np.argmax(q_table[state]) # Exploit learned values

        next_state, reward, done, info = env.step(action) 
        
        old_value = q_table[state, action]
        next_max = np.max(q_table[next_state])
        
        new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
        q_table[state, action] = new_value

        if reward == -10:
            penalties += 1

        state = next_state
        epochs += 1
        
    if i % 100 == 0:
        clear_output(wait=True)
        print(f"Episode: {i}")

print("Training finished.\n")

# %%
"""Evaluate agent's performance after Q-learning"""

total_epochs, total_penalties = 0, 0
episodes = 100

for _ in range(episodes):
    env.reset()
    # Crea el estado inicial
    state = env.encode(3, 1, 2, 0)
    env.s = state
    # Inicializa las epochs, penalties y rewards
    epochs, penalties, reward = 0, 0, 0

    done = False
    actions = []
    while not done:
        # Elige la accion que te indique el maximo valor de la q_table
        action = np.argmax(q_table[state])
        actions.append(action)
        # Ejecuta la accion
        state, reward, done, info = env.step(action)

        # Actualiza el valor de penalties si el reward es -10
        if reward == -10:
            penalties += 1

        epochs += 1

    total_penalties += penalties
    total_epochs += epochs

print(f"Results after {episodes} episodes:")
print(f"Average timesteps per episode: {total_epochs / episodes}")
print(f"Average penalties per episode: {total_penalties / episodes}")

# %%
actions

# %%
"""Evaluate agent's performance after Q-learning"""

total_epochs, total_penalties = 0, 0
episodes = 100

for _ in range(episodes):
    env.reset()
    # Crea el estado inicial
    state = env.encode(3, 1, 2, 0)
    env.s = state
    # Inicializa las epochs, penalties y rewards
    epochs, penalties, reward = 0, 0, 0

    done = False
    actions = []
    while not done:
        # Elige la accion que te indique el maximo valor de la q_table
        action = env.action_space.sample()
        actions.append(action)
        # Ejecuta la accion
        state, reward, done, info = env.step(action)

        # Actualiza el valor de penalties si el reward es -10
        if reward == -10:
            penalties += 1

        epochs += 1

    total_penalties += penalties
    total_epochs += epochs

print(f"Results after {episodes} episodes:")
print(f"Average timesteps per episode: {total_epochs / episodes}")
print(f"Average penalties per episode: {total_penalties / episodes}")

# %% [markdown]
# ahora vamos con algo mas dificil

# %% [markdown]
# ## Mario
#
# ![foto9](img/DDQN-1.gif)

# %% [markdown]
# Homer le asignamos una tarea?

# %% [markdown]
# # ...

# %% [markdown]
# ![foto10](img/homero-homer.gif)

# %% [markdown]
# ## FrozenLake

# %%
# crear e inicializar el env
env = gym.make('FrozenLake-v1', is_slippery=False)

# %%
env.reset()

# %%
env.render()

# %%
is_done = False
t = 0
while not is_done:
    action = env.action_space.sample()
    state, reward, is_done, _ = env.step(action)
    env.render()
    t += 1
print('\nlast state =', state)
print('reward = ', reward)
print('time steps =', t)

# %%
state, reward, is_done, _ = env.step(action)
