# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_csv('Datasets Energia/World_Nuclear_Power_Reactors.csv', encoding='latin1')
df.head()
# Out:
#   Location Reactor Name            Model Reactor Type Net Capacity (MWe)  \
# 0      NaN     Atucha 1         PHWR KWU         PHWR                340
# 1      NaN      Embalse          CANDU 6         PHWR                608
# 2      NaN     Atucha 2         PHWR KWU         PHWR                693
# 3      NaN   Armenian 2       VVER V-270          PWR                416
# 4      NaN    Rooppur 1  VVER-1200/V-523          PWR           1200 MWe
#
#   Construction Start First Grid Connection              Status     Country  \
# 0            1968-06               1974-03             Working   Argentina
# 1            1974-04               1983-04             Working   Argentina
# 2            1981-07               2014-06             Working   Argentina
# 3            1975-07               1980-01             Working     Armenia
# 4             Nov-17                  2024  Under Construction  Bangladesh
#
#    Unnamed: 9
# 0         NaN
# 1         NaN
# 2         NaN
# ...

# %%
df.dtypes
# Out:
# Location                  object
# Reactor Name              object
# Model                     object
# Reactor Type              object
# Net Capacity (MWe)        object
# Construction Start        object
# First Grid Connection     object
# Status                    object
# Country                   object
# Unnamed: 9               float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Location               185 non-null    object
#  1   Reactor Name           601 non-null    object
#  2   Model                  447 non-null    object
#  3   Reactor Type           591 non-null    object
#  4   Net Capacity (MWe)     605 non-null    object
#  5   Construction Start     375 non-null    object
#  6   First Grid Connection  456 non-null    object
#  7   Status                 606 non-null    object
#  8   Country                606 non-null    object
#  9   Unnamed: 9             0 non-null      float64
# dtypes: float64(1), object(9)
# memory usage: 47.6+ KB

# %%
df.columns
# Out:
# Index(['Location', 'Reactor Name', 'Model', 'Reactor Type',
#        'Net Capacity (MWe)', 'Construction Start', 'First Grid Connection',
#        'Status', 'Country', 'Unnamed: 9'],
#       dtype='object')

# %%
df.shape
# Out:
# (607, 10)

# %%
df.groupby(['Country', 'Location', 'Reactor Name'])[['Net Capacity (MWe)', 'Construction Start', 'First Grid Connection', 'Status', 'Model',
'Reactor Type', 'Status']].max()
# Out:
#                                         Net Capacity (MWe) Construction Start  \
# Country Location    Reactor Name
# China   Fujian      Fuqing 1&2                    1000 MWe                NaN
#                     Fuqing 3&4                    1000 MWe                NaN
#                     Fuqing 5&6                    1075 MWe                NaN
#                     Ningde 1&2                    1018 MWe                NaN
#                     Ningde 3&4                    1018 MWe                NaN
# ...                                                    ...                ...
# USA     Waterford   CE 2-loop (DRY)                   1168          14-Nov-74
#         Watts Bar   WH 4-Loop (ICECOND)               1164          20-Jul-73
#         Wolf Creek  WH 4-Loop (DRY)                   1200          31-May-77
#         Yankee Rowe WH (DRY)                           167           1-Nov-57
#         Zion        WH (DRY)                          1040           1-Dec-68
#
# ...
